# %%
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt

sns.set(style="whitegrid",font_scale=2)
import matplotlib.collections as clt

# %pip install ptitprince
import ptitprince as pt
# Out:
# Requirement already satisfied: ptitprince in /home/mac/anaconda3/lib/python3.9/site-packages (0.2.7)
# Requirement already satisfied: scipy in /home/mac/anaconda3/lib/python3.9/site-packages (from ptitprince) (1.7.3)
# Requirement already satisfied: seaborn==0.11 in /home/mac/anaconda3/lib/python3.9/site-packages (from ptitprince) (0.11.0)
# Requirement already satisfied: matplotlib in /home/mac/anaconda3/lib/python3.9/site-packages (from ptitprince) (3.5.1)
# Requirement already satisfied: numpy>=1.20 in /home/mac/anaconda3/lib/python3.9/site-packages (from ptitprince) (1.21.5)
# Requirement already satisfied: pandas>=0.23 in /home/mac/anaconda3/lib/python3.9/site-packages (from seaborn==0.11->ptitprince) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mac/anaconda3/lib/python3.9/site-packages (from matplotlib->ptitprince) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/mac/anaconda3/lib/python3.9/site-packages (from matplotlib->ptitprince) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /home/mac/anaconda3/lib/python3.9/site-packages (from matplotlib->ptitprince) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/mac/anaconda3/lib/python3.9/site-packages (from matplotlib->ptitprince) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in /home/mac/anaconda3/lib/python3.9/site-packages (from matplotlib->ptitprince) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mac/anaconda3/lib/python3.9/site-packages (from matplotlib->ptitprince) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mac/anaconda3/lib/python3.9/site-packages (from matplotlib->ptitprince) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in /home/mac/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn==0.11->ptitprince) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/mac/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->ptitprince) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load the exercise dataset
penguins = sns.load_dataset("penguins")
print(penguins)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
f, ax = plt.subplots(figsize=(20, 8))

pt.RainCloud(x="species", y="body_mass_g", data=exercise, palette="Set2", bw=0.2,
             width_viol=1.0, ax=ax, orient='h')

plt.title("Raincloud plot")
plt.show()
